# %%
import pandas as pd

# %% [markdown]
# https://meta.wikimedia.org/wiki/List_of_Wikipedias

# %% [markdown]
# # Download samples of Wikipedia in multiple languages

# %%
tables = pd.read_html('https://meta.wikimedia.org/wiki/List_of_Wikipedias')

# %%
len(tables)
# Out:
# 9

# %%
all_langs = pd.concat(tables[0:8], ignore_index=True)
all_langs = all_langs[all_langs.Articles > 0].copy()

# %%
all_langs
# Out:
#        №       Language       Language (local) Wiki Articles     Total  \
# 0      1        English                English   en  6522949  56115029
# 1      2        Cebuano  Sinugboanong Binisaya  ceb  6125836  11231578
# 2      3         German                Deutsch   de  2700621   7458794
# 3      4        Swedish                Svenska   sv  2551055   6110382
# 4      5         French               Français   fr  2432573  12080528
# ..   ...            ...                    ...  ...      ...       ...
# 320  321      Hiri Motu              Hiri Motu   ho        3       129
# 321  322     Sichuan Yi                     ꆇꉙ   ii        3       189
# 322  323           Afar                   Afar   aa        1       510
# 323  324  Northern Luri            لۊری شومالی  lrc        1       237
# 324  325       Muscogee               Muskogee  mus        1       115
#
#           Edits Admins     Users Active Users   Files Depth
# 0    1091916972   1034  43848293       118305  894011  1125
# 1      34857733      6     91542          173       0     2
# 2     222426812    193   3947411        17446  128572    93
# 3      50520284     66    825828         2051       0    16
# 4     194298530    159   4406976        17874   68725   253
# ..          ...    ...       ...          ...     ...   ...
# 320        3786      1      1575            0       0    --
# 321       11653      1      2031            0       0    --
# 322        4685      1      4061            2       0    --
# 323      140064      1      5036            1       0    --
# 324        3603      1      2348            0       0    --
#
# [325 rows x 12 columns]

# %%
import requests

# %%
from tqdm.auto import tqdm, trange

# %%
import numpy as np

# %%
import random

# %%
w = all_langs.Articles.values ** (1/5)
w /= sum(w)
sum(w)
# Out:
# 0.999999999999999

# %% [markdown]
# ## Scrape the texts

# %% [markdown]
# Sample the languages with temperature sampling.

# %%
import threading
from bs4 import BeautifulSoup
import time

# %%
def get_page(lang, timeout=0.1):
    res = requests.get(f'https://{lang}.wikipedia.org/wiki/Special:Random')
    if '<title>Wikimedia Error</title>' in res.text:
        time.sleep(timeout)
        return get_page(lang, timeout=timeout*2)
    return [res.url, res.text]

# %%
def url2lang(url):
    return url.split('//')[1].split('.')[0]

url2lang('https://en.wikipedia.org/wiki/Dunbar_Duncan')
# Out:
# 'en'

# %%
from collections import defaultdict

# %%
pages[0][0]
# Out:
# 'https://en.wikipedia.org/wiki/Dunbar_Duncan'

# %%
pages[0][0].split('//')[1].split('.')[0]
# Out:
# 'en'

# %%
get_paragraphs(pages[1][1])
# Out:
# ['Bukid ang Kūh-e Bandāv-e Zard (Pinulongang Persiyano: کوه بنداو زرد) sa Iran.[1] Nahimutang ni sa lalawigan sa Yazd, sa sentro nga bahin sa nasod, 500 km sa habagatan-sidlakan sa Tehrān ang ulohan sa nasod. 2,519 metros ibabaw sa dagat kahaboga ang nahimutangan sa Kūh-e Bandāv-e Zard,[1] o 76 ka metros sa ibabaw sa naglibot nga tereyn[saysay 1]. Mga 2.0 ka kilometro ang gilapdon sa tiilan niini.[saysay 2]\n',
#  'Ang yuta palibot sa Kūh-e Bandāv-e Zard kasagaran kabungtoran, apan sa sidlakan nga kini mao ang kabukiran.[saysay 3] Ang kinahabogang dapit sa palibot dunay gihabogon nga 2,631 ka metro ug 2.5 km sa amihanan-kasadpan sa Kūh-e Bandāv-e Zard.[saysay 4] Dunay mga 3 ka tawo kada kilometro kwadrado Hapit nalukop sa desiyerto ug kamingawan ang palibot sa Kūh-e Bandāv-e Zard may kaayo gamay nga populasyon.[3] Sa palibot sa Kūh-e Bandāv-e Zard.[4] Sa rehiyon palibot sa Kūh-e Bandāv-e Zard, kabukiran, ug mga tubud talagsaon komon.[saysay 5]\n',
#  'Ang klima bugnaw nga ugahon.[5] Ang kasarangang giiniton 22 °C.  Ang kinainitan nga bulan Hulyo, sa 34\xa0°C, ug ang kinabugnawan Enero, sa 6\xa0°C.[6] Ang kasarangang pag-ulan 121 milimetro matag tuig. Ang kinabasaan nga bulan Nobiyembre, sa 25 milimetro nga ulan, ug ang kinaugahan Hunyo, sa 1 milimetro.[7]\n',
#  '\n']

# %%
pages = []

# %%
from multiprocessing.pool import ThreadPool
pool = ThreadPool(processes=100)

# %% [markdown]
# %%time
# async_result = pool.map(get_page, all_langs.Wiki.tolist())

# %%
for i in trange(10):
    async_result = pool.map(get_page, all_langs.Wiki.tolist())
    pages.extend(async_result)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
for i in trange(100):
    if i % 5 == 0:
        # uniform
        langs = all_langs.Wiki.tolist()
    else:
        # heated distribution
        langs = all_langs.Wiki.loc[random.choices(range(len(all_langs)), weights=w, k=len(all_langs))].tolist()
    async_result = pool.map(get_page, langs)
    pages.extend(async_result)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ConnectionResetError: [WinError 10054] Удаленный хост принудительно разорвал существующее подключение
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     768             if value.__traceback__ is not tb:
# --> 769                 raise value.with_traceback(tb)
#     770             raise value
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\urllib3\util\ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# c:\users\david\appdata\local\programs\python\python39\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3976/466433455.py in <module>
#       6         # heated distribution
#       7         langs = all_langs.Wiki.loc[random.choices(range(len(all_langs)), weights=w, k=len(all_langs))].tolist()
# ----> 8     async_result = pool.map(get_page, langs)
#       9     pages.extend(async_result)
#
# c:\users\david\appdata\local\programs\python\python39\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# c:\users\david\appdata\local\programs\python\python39\lib\multiprocessing\pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# c:\users\david\appdata\local\programs\python\python39\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# c:\users\david\appdata\local\programs\python\python39\lib\multiprocessing\pool.py in mapstar(args)
#      46
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#      49
#      50 def starmapstar(args):
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
# ----> 5         return get_page(lang, timeout=timeout*2)
#       6     return [res.url, res.text]
#
# ~\AppData\Local\Temp/ipykernel_3976/3188366887.py in get_page(lang, timeout)
#       1 def get_page(lang, timeout=0.1):
# ----> 2     res = requests.get(f'https://{lang}.wikipedia.org/wiki/Special:Random')
#       3     if '<title>Wikimedia Error</title>' in res.text:
#       4         time.sleep(timeout)
#       5         return get_page(lang, timeout=timeout*2)
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'Удаленный хост принудительно разорвал существующее подключение', None, 10054, None))

# %% [markdown]
# for i in trange(1_000_000):
#
#     if random.random() < 0.2:
#         # uniform
#         idx = random.choice(range(len(all_langs)))
#     else:
#         # heated uniform
#         idx = random.choices(range(len(all_langs)), weights=w)[0]
#     lang = all_langs.Wiki.loc[idx]
#     res = requests.get(f'https://{lang}.wikipedia.org/wiki/Special:Random')
#     pages.append([res.url, res.text])

# %%
len(pages)
# Out:
# 93600

# %% [markdown]
# ## put texts by language together

# %%
import re

def get_paragraphs(html):
    soup = BeautifulSoup(html)
    body = soup.find('div', {'id': 'bodyContent'})
    if not body:
        return []
    # todo: remove <sup> elements
    # 
    result = []
    for p in body.findAll('p'):
        for bad_tag in ['sup', 'style', 'script']:
            for unwanted in p.find_all(bad_tag):
                unwanted.extract()
        text = p.text.replace('\xa0', ' ')
        if text.strip():
            result.append(text)
    return result

# %%
url, html = random.choice(pages)
print(url)

print(get_paragraphs(html))
# Out:
# https://ce.wikipedia.org/wiki/%D0%9A%D0%B0%D0%BD%D0%B0%D0%B9_(%D0%90%D0%BA%D1%82%D0%BE%D0%B1%D0%B5%D0%BD_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D1%8C)
# ['Канай — Кхазакхстанан Актобен областан Хобдинан кӀоштара эвла.\n', 'Кхузахь климат барамехь континентан ю, аьхка йовха хуьлу, ткъа Ӏа барамехь-шийла хуьлу. Шаран уггаре а бовха бутт бу — июль (мангалан), уггаре а шийла — январь (кхолламан).\n', 'Кеп:Хобдинан кӀошт\n']

# %%
lang2texts = defaultdict(list)

# %%
for url, html in tqdm(pages):
    lang2texts[url2lang(url)].extend(get_paragraphs(html))
# Out:
#   0%|          | 0/93600 [00:00<?, ?it/s]

# %%
for k in sorted(lang2texts.keys()):
    v = [x for x in lang2texts[k] if x.strip()]
    if not v: 
        continue
    print(k, len(v))
    for i in range(2):
        print(random.choice(v))
# Out:
# aa 1
# Wikipedia bödero kœáth amliethog e rhyδ gē gell tō un gelœga. Denn grëað zero œáthws ar ðechre di zera gentannwm hon.
# Template:Link FA
#
# Wikipedia bödero kœáth amliethog e rhyδ gē gell tō un gelœga. Denn grëað zero œáthws ar ðechre di zera gentannwm hon.
# Template:Link FA
#
# ab 241
# 617 (фышәи жәибжь) шықәса — иулиантәи амзар 617-тәи ашықәс ауп.
#
# 1439 (зқьы ԥшьышәи ҩажәи зеижә) шықәса — иулиантәи амзар 1439-тәи ашықәс ауп.
#
# ace 361
# Panté Gajah nakeuh gampông di Peusangan, Kabupatèn Bireuen, Acèh. Lumbôi gampông nyoe nakeuh 11.11.05.2006.
#
# Robert Scott Adsit (1965 – ) nakeuh sidroe aktor asay Amirika Syarikat.
#
# ady 524
# Къэрал тхьаматэр – Кая Каллас.
#
# тӀы
#
# af 1527
# Die bekendste seerowers in die Middeleeuse Europa was die Wikings, seevegters van Skandinawië wat hoofsaaklik tussen die 8ste en 12de eeu geroof en geplunder het; dit was die Wikingtydperk van die vroeë Middeleeue. Hulle het rooftogte uitgevoer op die kus, riviere en binnelandse stede van die hele Wes-Europa tot so ver as Sevilla, wat in 844 deur die Nore aangeval is. Wikings het ook die kus van Noord-Afrika en Italië aangeval en die hele kus van die Oossee geplunder. Sommige het met die riviere van Oos-Europa langs gevaar tot so ver as die Swartsee en Persië. Die gebrek aan ’n gesentraliseerde mag in Europa gedurende die Middeleeue het meegebring dat seerowers skepe en kusstreke oor die hele kontinent kon aanval sonder dat daar teen hulle opgetree is.
#
# Van die 13de eeu af het die Wokou, wat in Japan gebaseer was, hulle debuut in Oos-Asië gemaak en invalle gedoen wat 300 jaar lank sou voortduur. Hulle strooptogte het in die 1550's ’n hoogtepunt bereik – teen daardie tyd was die Wokou bloot Chinese smokkelaars wat sterk gereageer het op die Ming-dinastie se streng beperkings op privaat seehandel.
#
# ami 915
# Germany（德國）
#
# Itini i 33 00 N, 44 00 E, noAsiya ko Iraq.
# Polong no sekalay i 438,317 sq km “saka 59 ko rayray no ngangan. ”
# “O sekalay no sera i, 437,367 sq km, no nanom a sekalay i, 950 sq km ”
# Polong i 38,146,025 ko tamdaw.
#
# an 968
# Berryz Kobo
#
# A Imachen por Resonancia Magnetica (IRM), ye una tecnica d'imachen medica emplegada en radiolochía ta visualizar a estructura interna y o funcionamiento d'o cuerpo. A resonancia magnetica nucleyar (RM) proporciona un contraste muito mas gran entre os diferents teixius tovos d'o cuerpo que no a tomografía computada (TC), por o que ye util mas que mas en neurolochía (cerebro), l'aparello musculoesquelitoc, o sistema cardiovascular y a detección y seguimiento de cáncers (oncolochía). A diferencia d'a TC, no fa servir radiación ionizant, pero emplega un potent campo magnetico ta aliniar a magnetización nucleyar d'os atomos d'hidrocheno (normalment), en l'augua d'o cuerpo. S'emplegan campos de radiofreqüencia ta alterar sistematicament l'aliniación d'ista magnetización, fendo que os nuclios d'hidrocheno produzcan un campo magnetico de rotación detectable por o escáner. Iste sinyal se puet manipular por atros campos magneticos ta creyar a información suficient ta construir una imachen d'o cuerpo.
#
# ang 616
# Swa swa his manige lēodas, hæfþ Seofenburga land syndrige naman.  Germaniafolc gief hit þone naman "Siebenbürgen", se is seofen byrig.  Ungere secgaþ Erdély and Rumǣniefolc Ardeal oþþe Transilvania.  On Lǣden is hit Transylvia, se menþ land ofer wealde.
#
# ))(bye  21
# 0
#
# ar 2147
# - آل جراح (الفرع).
#
# الحب متلازمة الصف الثامن وأوهام أخرى! تيك أون مي على موقع IMDb (الإنجليزية)
#
# arc 239
# ܣܦܪܐ ܕܚܓܝ (ܥܒܪܐܝܬ ספר חַגַּי) ܗܘ ܚܕ ܡܢ ܣܦܪ̈ܐ ܕܬܢܟ ܘܕܕܝܬܝܩܝ ܥܬܝܩܬܐ ܕܐܬܟܬܒ ܗܘܐ ܡܢ ܚܓܝ ܢܒܝܐ܀
#
# ܩܘܦܐ ܗܘ ܚܝܐ ܟܘܝܐ ܡܢ ܬܓܡܐ ܕܒܙܝܬܐ܀
#
# ary 667
# آيت وابلي جماعة ترابية قروية كاينة في إقليم طاطا، جهة سوس ماسة، ساكنين فيها 2401 نسمة، على حسب الإحصاء العام 2014.
#
# ف 26 يوليوز، خرّجات لحوكومة واحد لقرار ف لعشية كيمنع دخول ؤ لخروج من لمدون ديال طانجا، تطوان، فاس، مكناس، دارلبيضا، برشيد، سطات، ؤ مراكش، غادي يتطبق من طناش د ليل؛ شي لي خلا ناس تجري ؤ تقبط طريق بزربة، تسمات علا ديك ليلة بليلة د لهروب لكبير.
#
# arz 1653
# 153289 ريبيكاواتسون كويكب بيتبع حزام الكويكبات الموجود بين كوكب المريخ و كوكب المشترى, اتسمى بالاسم ده على اسم ريبيكا واتسون.
#
#
# Matela ke Petit Gennevilliers, raltadukafa kepaita •
# Matelafa lanivawa is nomarna, Petit Gennevilliers •
# Kolanixo ke matela, Petit Gennevilliers •
# Matela ke Petit Gennevilliers bak fentugal
#
# awa 292
# फ़ैसलाबाद पाकिस्तान कय यक्ठु सहर होय ।
#
# पूर्वाभास हिन्दी भाषा कय एक्ठु पत्रिका होय ।
#
# ay 807
# Markawillka jisk'a t'aqa suyuxa (kastilla aru: Distrito de Marcavelica).  Piruwna mä jisk'a t'aqa suyuwa, Piwra jach'a suyu, Sullana jisk'a suyu.
#
# 13°55'41 71°29'50 - 14°52'58 72°0'
#
# az 2185
# INSEE kodu — 38560. Kommunanın 1999-cı il üçün əhalisi 940 nəfər təşkil edirdi. Kommuna dəniz səviyyəsindən 384 ilə 775 qədər metr yüksəklikdə yerləşir. Kommuna Parisdən təxminən 450 km cənub-şərqdə, Liondan 60 km cənub-şərqdə, Qrenobldan 39 km şimal-qərbdə yerləşir.
#
# Berjenyi 20 yaşından (1796) başlayaraq poemalar yazmağa başlamışdı, lakin onları dostlarından və ailəsindən gizləyirdi. 1803-cü ildə övladlarının xaç atası Yanoş Kiş onun poemalarını gördü və əsərlərindən üçünü Ferents Kazintsiyə göndərdi. Kazintsi əsərləri oxudu və Berjenyiyə mail yazaraq əsərləri haqqında ilkin təəssüratlarını onunla bölüşdü. Berjenyi də ona cavab yazdı və beləcə, onlar arasında uzunmüddətli məktublaşmalar başladı.
#
# azb 835
# قارداش پروژه‌لرده قاس شیلینق گؤره داها آرتیق بیلگی‌لر تاپابیلرسینیز.
#
# قارداش پروژه‌لرده ایسکرانتون، کانزاس گؤره داها آرتیق بیلگی‌لر تاپابیلرسینیز.
#
# ba 2704
# Б. э. т. 480 йылдың 28 сентябрендә иртән фарсы флоты һөжүм башлай. Фемистоклдың ҡыҫҡа телмәренән һуң караптар диңгеҙгә сыға.
#
# 1991 йылдан 1992 йылға тиклем— Халыҡ-ара ойошмаларҙың идаралыҡ начальнигы СССР Сит ил эштәре министрлығының. 1992 йылда Рәсәй Сит ил эштәре министрлығының халыҡ-ара ойошмалар һәм глобаль проблемалар Департаментының директоры итеп тәғәйенләнә.
#
# ban 1018
# ring Tira pinaka Tuha Saddhana, Dikara ring pasidangan ring Surih
#
# ulih senapati sadar taña kinuandha
#
# bar 1575
# As Gmoagebiet wead vo da Départementsstroß D42 vasoagd, im Westn valaffd de Autoboh A6, vo dea ob do a westliche Ortsumgehung vo Lyon in Planung is.
#
# Da urspringliche Noma Kaldeberg bsteht aus zwoa Tei, de im Zammhong mid da geografischn Log stehn. Kaltenberg liegt obahoib vo da Kahl (middlhochdeitsch: kalde) am Beaghong (mhd.: bërc). Im Kahlgründa Dialekt werd da Ort "Kaldeberch" gnennt.
#
# bat-smg 440
# Black Ribbons (2010; с Шутър Дженингс) ·
# Ghost Brothers of Darkland County (2012; с Джон Меленкамп)
#
#
# bh 532
# संगीतकार - लक्ष्मीकांत-प्यारेलाल
# गीतकार - संतोष आनंद
#
# सम्पूर्ण मानव सभ्यता के दिखावे खातिर विश्व एगो साधारण वाक्य ह, विशेषत: मानव अनुभव, इतिहास या मानव के सामान्य स्थिती के दर्शावे खातिर। उदाहरण:पृथ्वी पर कउनो भी स्थान।
#
# bi 302
# Pakistan - Palau - Palestine - Panama - Papua Niugini - Paragwae - Peru - Filipin - Polan - Portugal
#
# Avila
#
# bjn 548
# Suklat rancaknya dibari'akan sabagai hadiah atawa bingkisan wayah hari raya. Awan tawas, curak, wan rasa nang unik, suklat rancak dipurukakan sabagai tanda tarima kasih, dukungan, atawa pahatian. Bahanu jua sabagai panyataan cinta.
#
# Suklat rancaknya dibari'akan sabagai hadiah atawa bingkisan wayah hari raya. Awan tawas, curak, wan rasa nang unik, suklat rancak dipurukakan sabagai tanda tarima kasih, dukungan, atawa pahatian. Bahanu jua sabagai panyataan cinta.
#
# bm 392
# Donotulu
#
# Jean-Marie Le Pen (La Trinité-sur-Mer, 1928 - ), Fàransi politikimɔgɔ do.
#
# bn 2154
# ভিক্টোরিয়া জুবিলি সরকারি উচ্চ বিদ্যালয় (সংক্ষেপে ভি. জে. সরকারি উচ্চ বিদ্যালয়) চুয়াডাঙ্গা জেলার একটি ঐতিহ্যবাহী বিদ্যালয়। ১৮৮০ সালে স্কুলটিকে চুয়াডাঙ্গা সদরে প্রতিষ্ঠা করা হয়। মুক্তিযুদ্ধের সময় বিদ্যালয়টিতে মুক্তিবাহিনীর ট্রেনিং দেওয়া হতো। বিদ্যালয়টি চুয়াডাঙ্গা জেলার মাথাভাঙ্গা নদীর তীরে অবস্থিত। স্কুলটি প্রভাতী ও দিবা এই দুই শিফটে বিভক্ত। স্কুলটিতে ৩য় থেকে ১০ম শ্রেণী পর্যন্ত শিক্ষা দেয়া হয়।
#
# এ এফ এম মফিজুল ইসলাম ২০১৯ সালের ২৪ নভেম্বর ঢাকায় অবস্থিত বেসরকারি বিশ্ববিদ্যালয়, সাউথইস্ট ইউনিভার্সিটির উপাচার্যের দায়িত্বভার গ্রহণ করেন।
#
# bo 1221
# དེ་ལྟ་བས་ན་ཤེས་རབ་ཀྱི་ཕ་རོལ་ཏུ་ཕྱིན་པའི་སྔགས།
# རིག་པ་ཆེན་པོའི་སྔགས།
# བླ་ན་མེད་པའི་སྔགས།
# མི་མཉམ་པ་དང་མཉམ་པའི་སྔགས།
# སྡུག་བསྔལ་ཐམས་ཅད་རབ་ཏུ་ཞི་བར་བྱེད་པའི་སྔགས།
# མི་བརྫུན་པས་ན་བདེན་པར་ཤེས་པར་བྱེ་སྟེ།
# ཤེས་རབ་ཀྱི་ཕ་རོལ་ཏུ་ཕྱིན་པའི་སྔགས་སྨྲས་པ།
# ཏ་དྱ་ཐཱ། ཨོཾ་ག་ཏེ་ག་ཏེ་པཱ་ར་ག་ཏེ། པཱ་ར་སཾ་ག་ཏེ།
# བོ་དྷི་སྭཱ་ཧཱ།
# ཤཱ་རིའི་བུ་བྱང་ཆུབ་སེམས་དཔའ་སེམས་དཔའ་ཆེན་པོས་དེ་ལྟར་
# ཤེས་རབ་ཀྱི་ཕ་རོལ་ཏུ་ཕྱིན་པ་ཟབ་མོ་ལ་བསླབ་པར་བྱའོ།།
#
# ཕྱི་ནང་ཀུན་ལ་ཤེས་བྱའི་ནོར་གྱིས་ཁེངས། །
#
# bpy 1837
# নিবন্ধ এহান তিলপারাষ্ট্র (মার্কিন যুক্টরাষ্ট্র)র গজে লয়নাসে নিবন্ধহান। মনেইলে লয়করানিত পাংকরিক।
#
# জর্জিয়া (রাষ্ট্র)র পুরা নাঙহান জর্জিয়া (ইংরেজি:Georgia, জর্জিয়ান ঠার: Sakartvelo / საქართველო), এহান ইউরোপ মহাদেশ বারো মুঙেদের ইউরোপ উপমহাদেশর দেশ আহান। দেশ এহানর রাজধানীগ তব্লিসি।রাষ্ট্র এহানর মানুরে/নাগরিকরে জর্জিয়ান বুলতারা।
#
# br 1172
# Beg-bronntroet war-zu an diabarzh
#
# "Twisted Transistor"
#
# bs 1969
# SAO Hercegovina (Srpska autonomna oblast Hercegovina, SAO Istočna Hercegovina ili SAO Stara Hercegovina) bila je samoproglašena srpska autonomna oblast u SR BiH. Postojala je od 1991. do 1992, kada se ujedinila sa ostalim samoproglašenim srpskim autonomnim područjima u Bosni i Hercegovini i oformila Republiku Srpsku. Glavni grad ove oblasti bio je Trebinje, a SAO Hercegovini su pripadale općine sa većinskim srpskim stanovništvom.
#
# Mnogi od ovih refleksi su prilično složeni jer zahtijevaju uključivanje velikog broja sinapsi u velikom broju različitih jezgara u CNS (npr, refleks bijega). Ostali pomenuti uključuju funkciju samo nekoliko sinapsi (npr.refleks povlačenja). Procesi kao što su disanje, varenje, i održavanje otkucaja srca mogu se smatrati refleksima akcije, prema nekim definicijama pojma.
#
# bug 384
# Mézières-en-Drouais iyanaritu séuwa komun ri déparetema Eure-et-Loir ri Perancis.
#
# Plouagat iyanaritu séuwa komun ri déparetema Côtes-d'Armor ri Perancis.
#
# bxr 752
# Байгаалиин хии, газарай тоһон, хүнэһэнэй бүтээгдэхүүнэй томо үйлэдбэрилэгшын нэгэ Оклахомань ниидхэ, эршэм хүсэн, сахилгаан холбоо, биотехнологиин һалбари дээрэ тулгуурилһан эдэй засагтай. АНУ-ай эгээн хурдан ургажа нэмэгдэжэ бай эдэй засагтай тус можо улас нэгэ хүндэ ногдохо оролгын дэбжэлтэ болон дотоодын ниитэ бүтээгдэхүүнэй дэбжэлтээр дээгүүр байрада ородог. Оклахома-сити болон Тулза Оклахомагай эдэй засагай гол түбүүдэй үүргэ гүйсэдхэдэг ба можо уласай ниитэ хүн зоной 60 оршом хубинь эдэ хотын метрополитан бүһэдэ оршон һуудаг. Тус можо улас эдэй засаг, элүүр мэндын һалбарида холимог үзүүлэлтэтэй болоод эгээн томо ехэ һургуулинуудынь Америкын ехэ һургуулинуудай лигэдэ оролсодог.
#
#  Монгол
# Нютагай албан хэлэн:
#
# ca 2562
# El club acostuma a representar a la classe alta, mentre que el seu rival ciutadà, el Vålerenga representa a la classe treballadora.
#
# El 2014 Mientus va aparèixer en diversos episodis de la sèrie d'ABC Family Chasing Life. Aquest mateix any, va ser elegit per a un paper principal en la sèrie de CW The Flash com a Pied Piper. Mientus va fer història en el seu paper com a Pied Piper representant el primer supermalvat obertament homosexual.
#
# cbk-zam 644
# El 24 de agosto de 2016, Daniel Bryan (entonces gerente general de SmackDown) tuvo un altercado verbal con The Miz, en el que Bryan criticó la capacidad de lucha de The Miz y su estilo de lucha libre. The Miz luego respondió haciendo una diatriba acerca de las varias lesiones que Bryan había sufrido a lo largo de su carrera en la WWE.​ De ahí en adelante, Bryan y The Miz tendrían interacciones esporádicas durante más de un año. El 20 de marzo de 2018, después de otra lesión que amenazó su carrera, Bryan fue autorizado oficialmente para regresar al ring por médicos,​ y reanudó su feudo con The Miz, y pasó de interacciones esporádicas a los dos intercambiando palabras de forma regular. Esto continuó hasta el episodio del 31 de julio de SmackDown, donde Bryan desafió a The Miz a un combate en SummerSlam. Inicialmente, The Miz declinó el encuentro, afirmando que siempre había estado por encima de Bryan, y recomendó a Bryan regresar al circuito independiente una vez que su contrato con la WWE expirara.​ Sin embargo, la semana siguiente, The Miz aceptó el desafío de Bryan después de que se llevaran a cabo negociaciones entre los agentes de The Miz y la gerente general de SmackDown Paige.
#
# La infraestructura en Venezuela tuvo uno de sus mayores crecimiento en la dictadura del General Marcos Pérez Jiménez, y luego en los "booms petroleros" de los años 1970 y 80's. Se basa en una simbiosis entre la arquitectura contemporánea y la colonial, destacando entre ellas se encuentran las Torres de Parque Central, las cuales son unas de las torres más altas de Sudamérica, diversos centros comerciales a lo largo y ancho del país, etc.
#
# cdo 451
# Dâi-lièu-guók (大遼國), iâ hô̤ lā̤ Dâi-kié-dăng-guók (大契丹國) hĕ̤k-ciā Lièu-dièu (遼朝), sê Dṳ̆ng-guók lĭk-sṳ̄ gà̤-dēng gì siŏh ciáh iù Kié-dăng-nè̤ng gióng-lĭk gì guók-gă.
#
# Háng-cê cháung-cê guó-tiàng â̤ buong có̤ 6 lôi, cī le̤k cṳ̄ng cêu sê bàng-siòng gōng gì „Le̤k-cṳ (háng-cê iā có̤六書)“. Háng-guók gì Hṳ̄ Sêng gah i gì «Suók-ùng Gā̤icê» diē-siá ôi cī le̤k lôi cī diâng miàng ching, huong biék sê „cCiông-hìng (象形)“, „Cī-sê̤ṳ (指事)“, „Huôi-é (會意)“, „Hìng-siang (形聲)“, „Duōng-cuó (轉注)“, gâe̤ng „gā-cióh (假借)“.
#
# ce 1165
# Кхузахь сахьт Москохца нийса лелаш ду. Сахьтан аса ю UTC+3.
#
#
# Алексеевка (оьрс. Алексеевка) — Российн Федерацин Пензин областан Мокшанан кӀоштара эвла.
#
# ceb 1697
# Ang klima uga. Ang kasarangang giiniton 24 °C.  Ang kinainitan nga bulan Hulyo, sa 34 °C, ug ang kinabugnawan Enero, sa 13 °C. Ang kasarangang pag-ulan 75 milimetro matag tuig. Ang kinabasaan nga bulan Pebrero, sa 19 milimetro nga ulan, ug ang kinaugahan Hunyo, sa 1 milimetro.
#
# Parke ang Altın Beşik Mağarası Milli Parkı sa Turkeya. Nahimutang ni sa lalawigan sa Antalya, sa habagatan-kasadpang bahin sa nasod, 300 km sa habagatan sa Ankara ang ulohan sa nasod. 678 metros ibabaw sa dagat kahaboga ang nahimutangan sa Altın Beşik Mağarası Milli Parkı.
#
# ch 223
# Estados Unidus (United States of America) capitat Washington D.C.
#
# Ray City, nasong-song gi Estados Unidos. Guåha 1,040 na tataogues na populasion i sengsong nu i senso 2014.
#
# cho 116
# Hohltina, Hohltini
#
# Chahta: anumpa.
#
# chr 236
# ᏪᏌ • ᏍᎨᏆ • ᎯᎸᏍᎩ ᏥᏍᏆ • ᎧᎹᎹ • ᏑᎵ • ᎤᏔᎾ ᎠᏣᏗ • ᏎᎼᏂ • ᏧᎵᏍᏓᎾᎵ • ᎨᏯᏔᎯ ᎬᎾ • ᏙᏒᏓᎵ • ᏩᎶᏏ • ᏙᏯ • ᎤᎵᎾᏫ • ᏩᏚᎵᏏ • ᎠᏫ • ᏩᎴᎳ • ᎪᎦ
#
# ᎠᏁᏦᏗ (anetsodi)
#
# chy 288
# Táxemésêhestôtse, táxemôxe'êstónestôtse
#
# É-amôhoo'e.
#
# ckb 870
# گەرمک لە باکوور ھاوسنوورە لەگەڵ گوندی حەیدەرەسوورە و لە باشوور لەگەڵ شارەدێی زینانەی گەورە و لە ڕۆژھەڵات لەگەڵ گوندی پیرمۆنی لە ڕۆژاوا لەگەڵ گوندی وارانی بان غاز.
#
# ١٢.    دروست کردنی (٨) جۆگەی کۆنکریتی لە سنورەکە لە ساڵی (٢٠٠٥ تا ٢٠١٣)
#
# co 1022
# In u 2004 a stilista australiana di mamma libanese Aheda Zanetti, proprietaria di l'impresa Ahiida, perfiziuneghja u design di u custumu da bagnu (à l'iniziu chjamatu "hijood"), chì hè brivettatu à parte da u 2007 incù u nome rigistratu "Burchini", imprudendu materiale sinteticu lebbiu simile à i custumi nurmli da bagnu. U burchini fù aduttatu dopu da u guvernu australianu cum'è unu di i mudelli di divisa per u persunale feminile musulmanu impignatu in u salvamentu annantu à e spiaghje. In u 2016 Aheda Zanetti sustene d'avè vindutu guasi 500000 pezzi in dodici anni, incù vendite in custante aumentu.
#
# Qui qualchì esempiu di u vucabulariu brasilianu:
#
# cr 228
# ᐊᓯᐊ (english : Russia)
#
# President : Andrés Manuel López Obrador
#
# crh 349
# 1955 senesi — XX asırnıñ bir senesi.
#
# Thanks of Congress
# cs 2738
# 1930
#
# Max Theiler (1951) •
# Selman Abraham Waksman (1952) •
# Hans Adolf Krebs / Fritz Albert Lipmann (1953) •
# John Franklin Enders / Frederick Chapman Robbins / Thomas Huckle Weller (1954) •
# Hugo Theorell (1955) •
# André Frédéric Cournand / Werner Forßmann / Dickinson W. Richards (1956) •
# Daniel Bovet (1957) •
# George Wells Beadle / Edward Lawrie Tatum / Joshua Lederberg (1958) •
# Arthur Kornberg / Severo Ochoa (1959) •
# Frank Macfarlane Burnet / Peter Brian Medawar (1960) •
# Georg von Békésy (1961) •
# Francis Crick / James Dewey Watson / Maurice Wilkins (1962) •
# John Carew Eccles / Alan Lloyd Hodgkin / Andrew Fielding Huxley (1963) •
# Konrad Bloch / Feodor Lynen (1964) •
# François Jacob / André Lwoff / Jacques Monod (1965) •
# Francis Peyton Rous / Charles Brenton Huggins (1966) •
# Ragnar Granit / Haldan Keffer Hartline / George Wald (1967) •
# Robert W. Holley / Har Gobind Khorana / Marshall Warren Nirenberg (1968) •
# Max Delbrück / Alfred Hershey / Salvador Luria (1969) •
# Julius Axelrod / Ulf von Euler / Bernard Katz (1970) •
# Earl Wilbur Sutherland (1971) •
# Gerald Edelman / Rodney Robert Porter (1972) •
# Karl von Frisch / Konrad Lorenz / Nikolaas Tinbergen (1973) •
# Albert Claude / Christian de Duve / George Emil Palade (1974) •
# David Baltimore / Renato Dulbecco / Howard Martin Temin (1975)
#
# csb 646
# Błotnô chòszczka abò rozkòscérz (Equisetum palustre L.) – to je ôrt roscënë z rodzëznë chòszczkòwatëch (Equisetaceae). Ta chòszczka rosce m. jin. na Kaszëbach.
#
# ה'תקכ"ה — ה'תקכ"ו
#
# cu 418
# Netgear продава NAS устройства на малки предприятия и потребители под името на продукта ReadyNAS. С тази хардуерна линия за съхранение Netgear се бори с конкуренти като Buffalo, Zyxel и HP. Netgear навлезе на пазара за съхранение през май 2007 г., когато придоби Infrant (създател на линията ReadyNAS). През март 2009 г. Netgear започна да предлага интегрирано онлайн решение за архивиране, наречено ReadyNAS Vault.
#
# Вѣдьн҄ь
#
# cv 857
# Шаблон:AdobeCS
#
# Ял тăрăхĕнче климат вăтам континентлă. Хĕлле сивĕ, çилсем вĕреççĕ, çуллв ăшă. Хĕллехи вăтам температура — -12,9 °C тан, çуллахи — +18,3 °C. Палăртса юлнă чи сивĕ  температура — -44 °C, чи ăшши — +37 °C.
#
# cy 1214
# O dro i dro, mae Dora yn dod ar draws Swiper, llwynog sy'n lladrata. Er mwyn ei atal, rhaid i Dora ddweud "Swiper no swiping" dair gwaith. Weithiau mae disgwyl i'r gynulleidfa helpu Dora a Boots i ddod o hyd i'r eitemau sydd wedi'u dwyn. Maen nhw weithiau yn gorfod wynebu hen ellyll blin - "Grumpy Old Troll" - sy'n byw o dan bont y mae'n rhaid iddyn nhw ei chroesi. Mae'r ellyll yn rhoi rhigwm iddyn nhw ei ddatrys, eto gyda chymorth y gynulleidfa, cyn eu bod yn cael croesi.
#
# Rhestr Wicidata:
# da 1587
# En mening er et subjektivt sandhedsudsagn, en antagelse – i modsætning til et faktum (der anses for at være ubetvivleligt). Der er en anelse forskel på indholdet af henholdsvis "opfattelse" og "holdning", for mens opfattelser kan være meget flygtige, så forudsætter holdninger, at man har gjort en opfattelse til en del af sin personlighed.
#
# Preiļi (pól. Prele; łat. Preili) jo město w pódzajtšnej Letiskej, w Łatgalskej.
#
# dty 431
# लोलीको मोहन्याल कत्यूरी राजाका वंशजले स्यालपखे रावललाई साउपेको छ ।
#
# ऋचा शर्मा को जनम १६ जुलाइ १९८५ माइ धनगढी माइ भयाऽ हो। उन कैलाली जिल्ला माइ ठुलि भैन रे अच्याल काठमाडौं माइ बसन्छिन्।
#
# dv 932
# އިސްލާމި ނެރު v • d • e
#
# 1 ދަމު---------- ތެތް - ހޫނު
#
# dz 537
# དེ་མ་ཚད་མི་དབང་མཆོག་གིས་ འབྲུག་པའི་མི་སེར་ཚུ་ལུ་ རྒྱལ་ཁབ་ནང་རྒྱང་མཐོང་དང་ ཡོངས་འབྲེལ་གྱི་རིམ་ལུགས་འགོ་བཙུགས་ཞིནམ་ལས་ དེ་ལས་བརྟེན་ཏེ་ མི་རང་ར་སོ་སོ་ལུ་ ཕན་པ་དང་གནོད་པ་ཚུ་ ག་དེ་སྦེ་ཡོདཔ་ཨིན་ནའི་སྐོར་ལས་ཡང་བཤད་དེ་གནང་ཡོདཔ་ཨིན་མས། རྒྱང་མཐོང་དང་ཡོངས་འབྲེལ་ དེ་ལས་ རང་དང་རྒྱལ་ཁབ་ལུ་ ཕན་པ་དང་གནོད་པའི་ གནས་ཚུལ་ལེ་ཤ་ཡོདཔ་ལས་ ན་གཞོན་ཚུ་གིས་ དེ་ཚུ་དབྱེ་བ་ཕྱེ་སྟེ་འབད་དགོཔ་ ཁག་ཆེ་བའི་བཀའ་རྒྱ་ཚུ་ཡང་གནང་ཡོདཔ་ཨིན། འབྲུག་རྒྱལ་ཁབ་འདི་མི་རློབས་ཉུང་བའི་ རྒྱལ་ཁབ་ཅིག་ཨིན་རུང་ འཛམ་གླིང་གཅིག་གྱུར་གྱི་དུས་ཚོད་ལུ་ མཐུན་ལམ་ཅན་གྱི་རྒྱལ་ཁབ་ཚུ་དང་གཅིག་ཁར་ འབྲེལ་བ་འཐབ་སྟེ་ཚོང་འབྲེལ་དང་ ལྟ་བཤལ་ཡར་རྒྱས་གཏང་ནིའི་དོན་ལས་ སྤྱི་ལོ་ ༡༩༨༣ ཟླ་ ༡༡ པའི་ཚེས་ ༢ ལུ་ འབྲུག་མཁའ་འགྲུལ་ཡང་གཞི་བཙུགས་འབད་ཡོདཔ་མ་ཚད་ གཞན་ཡང་རླུང་འཕྲིན་ འགྲེམ་ ལྕགས་འཕྲིན་ བརྒྱུད་འཕྲིན་ འགྲུལ་འཕྲིན་ གློག་རིག་ གློག་འཕྲིན་ འགྲུལ་འཁོར་གཏོང་ལེན་ ཀུན་གསལ་ སྒེར་གྱི་གསར་ཤོག་ ལ་སོགས་པ་ཚུ་ཡང་གཞི་བཙུགས་མཛད་ཡོདཔ་ཨིན་མས། (ཀུན་བཟང་ཆོས་འཕེལ་དང་ རྣམ་རྒྱལ་ཕུན་ཚོགས། (༢༠༠༩)
#
#
# eml 1024
# 'L è stâ girâ a Ambûrg, Berlîṅ e Lóndra.
#
#
#
# Artéccol in dialètt mudnés
#
#
# en 5481
# This biographical article relating to German rowing is a stub. You can help Wikipedia by expanding it.
# After Barnard rejected subsequent merger proposals from Columbia and a one-year extension to the 1973 agreement expired, in 1977 the two schools began discussing their future relationship. By 1979 the relationship had so deteriorated that Barnard officials stopped attending meetings. Because of an expected decline in enrollment, in 1980 a Columbia committee recommended that Columbia College begin admitting women without Barnard's cooperation. A 1981 committee found that Columbia was no longer competitive with other Ivy League universities without women, and that admitting women would not affect Barnard's applicant pool. That year Columbia president Michael Sovern agreed for the two schools to cooperate in admitting women to Columbia, but Barnard faculty's opposition caused president Ellen Futter to reject the agreement.
#
# eo 1691
# Palačov, minibierfarejo
#
# 3854 George estas marsrenkonta asteroido malkovrita la 13-an de marto 1983 de la usona astronomino Carolyn S. Shoemaker elde la Observatorio de la Monto Palomar, apud San-Diego (Kalifornio, Usono).
#
# es 4416
# Después de colaborar en la coordinación de las categorías inferiores del C. A. Rosario Central, ejerció como ayudante del técnico Pablo Sánchez en el C. D. Universidad de Concepción,​ equipo con el que logró un ascenso y terminar en la cuarta posición de la Primera División de Chile.​ Durante 2015 desarrolló la misma función en el C. D. O'Higgins.​ A continuación, fue coordinador de fútbol en el colegio Inmaculada Jesuitas de Alicante y, en mayo de 2017, pasó a dirigir al Coquimbo Unido de la Primera B de Chile.​ El 4 de noviembre de 2018 consiguió el campeonato de la Primera B de Chile y el ascenso a Primera División.​ En diciembre de 2019 se confirmó su regreso a O'Higgins esta vez como técnico.​
#
# La fecha es desde el inicio de la aplicación hasta la fecha de finalización de la aplicación.
#
# et 1839
# Staadion on suur spordirajatis, kus on harilikult kaheksa jooksurajaga 400 m pikkune ovaalne jooksuring ning hüppe-, tõuke-, heite- ja viskealade kohad. Spetsialiseeritud staadionidel võib olla keskel normaalmõõtmetega jalgpalliväljak. Staadioni ümbritsevad pealtvaatajate tribüünid, tabloo, lisaks kuulub suuremate staadionide juurde teenindushooneid ja muud vajalikku.
#
# Erinevalt lambahänilasest puudub põhjahänilase isaslinnul valge kulmutriip.
#
# eu 1790
# Olavi Paavolainen (Kivennapa, 1903ko irailaren 17a - Helsinki, 1964ko uztailaren 19a) finlandiar idazle, poeta, entsegulari eta kazetaria izan zen. Tulenkantajat talde literarioaren parte izan zen, liberala eta Europazalea.
#
# 2020tik Save the children-eko Espainiako lehendakariordea da.
#
# ext 679
# Cenzillus:
#
#  - Total
#  - Densiá de puebración
#
# fa 1706
# این یک مقالهٔ خرد  یکی از آثار باستانی ایران است. می‌توانید با گسترش آن به ویکی‌پدیا کمک کنید.
# این یک مقالهٔ خرد فوتبال است. می‌توانید با گسترش آن به ویکی‌پدیا کمک کنید.
# ff 413
# Eɗen ciftora wonnde Jallo Teli heblaa ko he gannde jojjannde walla mbiyen ganndal sariyaaji (duruwaa), ko ɗuum waɗi nde o arti Gine tan Seku toɗɗii mo ko Jaagorɗo Kalfinaaɗo Ñaawooje. O wonii heen tuggude nde o art he 1972 haa 1976. He ngoon posto kadi o addi heen karallaagal timmungal e pellital gollaade ngal o anndiraa ngal. O wayli kuule leydi (code civil) ɗee, o itti ɗum en e ɗe ɓe ndonnoo e laamu koloñaal Farayse o wiɗti ɗum en kanum en fof kuule Ginenaaje. O naati kadi he lannda mbajja ka (Parti Démocratique Guinéen), wonnoka he jappeere ko aldaa e pooɗondiral. Hono kaadareeɓe lannda kaa fof ni, saha kala omo yaha he nder dowriiji he ngam daronoyaade lannda ka, kono kadi no kala kaadareeɓe leydi ndii kala ɗo yahi ko deenaaɗo o alaa wellitaare, o waawaa yaltude leydi ngam ɗannaade.
#
# Sir Ahmadu Bello Hambe teetii Lesdi Niseeriya gadda njuungo
#
# fi 2523
# Waltteri Torikka voitti MTV3:n Tähdet, tähdet -televisiosarjan toisen tuotantokauden finaalin vuonna 2015. Esikoisalbuminsa Sydän hän julkaisi 2015. Albumin ilmestymispäivänä Waltteri Torikka lähti viihdekonserttikiertueelle  esiintyen 10 paikkakunnan konserttisaleissa. Konserttisalikiertue päättyi Helsingin Musiikkitalon "Jouluinen Sydän" konserttiin, jossa häntä säesti Jyväskylän Sinfoniaorkesteri.
#
# I-7 - I-8
#
# fiu-vro 580
# Ku kõgõ kuulsambaq ommaq "Elemendiq" uma geomeetriä-osa poolõst, om sääl sõski ka arvoteooriat. Muuhulgan om sääl köüdüs tävveliidsi arvõ ja Mersenne'i lihtsidõ arvõ vaihõl, tõõstus, et lihtsit arvõ om lõpmalda pall'o, lemma arvõ faktorisiirmisõ kotsilõ (miä veese aritmeetiga põhiteoremini) ja Eukleidese algoritm katõ arvo kõgõ suurõmba ütidse jagaja löüdmises.
#
# Jassi oja om uja Urvastõ kihlkunnan.
#
# fj 389
# Melanesia e dua na subveiyasana ni Oceania mai na yanuyanu o Niu Kini ena loma ni ceva ra kei ni Wasa Pasifika ki Wasawasa Arafura, ka tokalau vei Toga.
#
# ira]
#
# fo 684
# Hann var Uttanríkisráðharri frá 2014 – 2014 og samskiftismálaráðharri frá 2006 til 2008.
#
# Dópur · Konfirmatión
# Hjúnaband
# Deyði · Jarðarferð
#
# fr 6135
# Misonne fut le septième fils de Louis Misonne, avocat et industriel, et d'Adèle Pirmez. Il étudia le génie minier à l'Université catholique de Louvain, mais n'exerça jamais comme ingénieur. Encore étudiant, il s'intéressa à la musique, à la peinture et, à partir de 1891, à la photographie sur laquelle il se concentra exclusivement à partir de 1896.
#
# Après d’importantes recherches menées au mois de mai 2019, la famille déclare ne pas croire à la thèse de l’accident et prépare de nouveaux déplacements pour poursuivre leur enquête. Elle doute également sur le fait que le dossier remis aux autorités françaises soit complet.
#
# frp 659
# En  Étalia :
#
# Grants rotes de cols ârpenches travèrsont lo Valês: la rota du Grant-Sent-Bèrnârd et les rotes de la Forclla et du Semplon.
#
# frr 826
# At regiuun hee tau departmenten.
#
#  Amerika Birleşik Devletläri  •
#  Bahamalar  •
#  Kanada  •
#
# gan 470
# 41：方42：趙43：夏44：丁45：孫46：龔47：易48：歐陽49：涂50：高
#
# 《豫章叢書》係套收納江西嗰全部歷史文獻最多卷帙、最全內容嗰大型叢書。佢攏共有兩部，1895年版同得1923年版。
#
# gcr 379
# Fachism-an sa roun sistenm politik otoritèr ki ka asosyé popilism, nasyonalism ké totalitarism o non di roun idéyal kolèktif souprenm. Mouvman révolisyonèr, li ka opozé so kò frontalman à démokrasi parlmantèr é à Léta libéral garan dé drwè endividjwèl. Isou di divèrs konpozant di filozofi éropéyenn di xixe syèk, fachism-an trouvé annan sirkonstans ékonomik-a é istorik di aprè-pronmyé lagèr mondjal kontèks-a ki pèrmèt li di aksédé o pouvwar, dabò an Itali annan lannen-yan 1920 ké Mussolini, épi anba roun varyant aksantchwé, militaris, an Almagn annan lannen-yan 1930 ké nazism-an ké Hitler.
#
# Lavil-a té marké pa rounlo linondasyon, don pli enpòrtan-yan anvan xxe syèk sa sa-ya di 583, 842, 1206, 1280, 1325, 1407, 1499, 1616, 1658, 1663, 1719, 1733, 1740, 1764, 1799, 1802, 1836, 1844 ké 1876. Pou péryòd résan-yan, pli enpòrtan-yan sa sa-ya di 1910, 1924, 1955, 1982 ké 2016.
#
# gd 588
# ‘S e baile beag ann an Cauca, Coloimbia, a th’ann Silvia. Tha e suidhichte aig 2600m os cionn ìre na mara aig astar dhe 59m bho Phopayán, ann an ceann a deas na dùthcha. Tha teodhachd meadhanach dhe 12˚ aige. Chaidh am baile a steidheachadh ann an 1562.
#
# Tha na tràighean gainmheil agus fada na phàirt Fife Coastal Path, a thèid a barrachd air 150 mìltean (240 km) bho Linne Foirthe do Linne Tatha. Tha slighean ann an Gleann Lìobhann agus Silverburn cuideachd.
#
# gl 2071
# A súa xubilación completa non se produciu ata 1980, cando tiña 75 anos. No entanto, en 1986 recibiu a encarga da Encyclopaedia Britannica para a elaboración dunha medalla que servise como Premio Britannia; este foi un dos seus derradeiros traballos.
#
# Illas e rocas do conxunto (19 en total), de norte a sur e segundo os seus nomes orixinais franceses:
#
# glk 1027
# تئران(اوستان)
#
# آب پری |
# لاریجان آب گرم |
# قرمرض آب معدنی |
# آلاشت |
# ایمامزاده کتی |
# بابلسر |
# چالدره پارک جنگلی |
# سی‌سنگان پارک جنگلی |
# دشت ناز پارک ملی |
# راه‌آهن ورسک پورد |
# محمدحسن‌خان پورد |
# نمک‌آبرود تله‌کابین  |
# جؤرده |
# نیما یوشیج خانه  |
# خشت‌پل |
# ولشت دریاچه  |
# سادات‌محله |
# آویدر سد خاکی  |
# لار سد  |
# علم‌کوه |
# کمربند غار  |
# شاهاندشت قلعه  |
# گردن قلعه  |
# رامسر کاخ  |
# باغ صفوی مجموعه  |
# آمل مسجید جامع  |
# بابل موزه  |
# خشکه‌داران موزه تاریخ طبیعی |
# کندلوس موزه  |
# ساری میدان ساعت  |
# رامسر هتل قدیم
#
# gn 838
# Ndojekuaaporãi moópa térã araka'épa heñoiva'ekue karai Luis Alberto Riart. Karai Osvaldo Kallsen he'i heñói hague Villa Floridape pe  21 jasypokõi ary 1880 jave. Ituvakuéra ha'e karai Jerónimo Riart  (catalán) ha kuñakarai Jerónima Vera y Aragón, paraguaigua (avei Eduardo Shaerer sy rérajoapy rehegua).
#
# Universidad Americana opyta guataha Brasília 1100, Barrio Jara Paraguaýpe, ha guereko 17 mbo´esyry. Umíva apytépe jajuhi Ingeniería en Informática, Periodismo, Ingeniería Industrial, Comercio Internacional, Derecho, Diseño Gráfico, Psicología, Economía, ha ambueve.
#
# gom 1741
# bhavam-bhoinnim modem
#
# ब्रिटिश इंपिरियल मानकां: लॉर्ड कॅरिसफॅार्ट हाचे अध्यक्षतेखाल संसदीय समितीन १७५८ - ६० ह्या वर्सा तयार करून घेतिल्लीं मानकां १८२४ त कायदेशीर करपांत आयलीं. १८२४ पसून सगळीं ब्रिटिश मानकां इंपिरियल मानकां म्हूण वळखूंक लागले. ५,७६० ट्रॉय पौंड हो मुखेल पौंडजालो आनी ॲव्हर द पॉइझ पौंड १६ औंसांचो आनी ७,००० ट्रॉय ग्रेनांचो थारायलो. इ.स. १८४३ त मुखेल पौंड मानाक ७,००० ग्रेनांचो ॲव्हर द पॅाइझ पौंड थारायलो आनी ट्रॅाय पौंड ५,७६० ॲव्हर द पॅाइझ ग्रेनांचो करपांत आयलो. १९१३ त ३ ⅓ ग्रेनांचो ( ट्रॅाय औंसाचो १५० वो भाग ) इंग्लीश वा हि-याचो कॅरेट सादारण उपेगांत उरलो. वखदाच्या पुरवठ्याखातीर ॲव्हर द पॅाइझ पौंड, औंस आनी ग्रेन सर्वसामान्य वापरांत आयले. तेउपरांत १९६३ तल्या अधिनेमाप्रमाण सगळी इंग्लीश वजनां आनी मापां हांचे मेट्रिक पद्दतींतल्या वजनांत आनी मापांत परत व्याख्या करपांत आयल्यो आनी तेउपरांत दोन वर्सांनी राश्ट्रीय पावंड्यार हो बदल वेव्हारांत येवपाक सुरवात जाली. वेपाराखातीर इंपिरियल मानक पौंड आनी विज्ञान तशेंच तंत्रविद्या हातूंत आंतरराश्ट्रीय पौंड (= ०.४५३५९२३२ आंतरराश्ट्रीय किग्रॅ.) मूलभूत थारावपांत आयले.
#
# gor 273
# Tirtajaya yito tala tuwawu lo kelurahan to Kecamatan Sukmajaya, Kota Depok, Provinsi Jawa Barat, Indonesia.
#
# Dudepo yito tala tuwawu lo desa to Kecamatan Anggrek, Kabupaten Gorontalo Utara, Provinsi Gorontalo, Indonesia.
#
# got 298
# 𐍆𐍂𐌰𐌿𐌾𐌹𐌽𐌰𐍃𐍃𐌿𐍃 𐌹𐌽 𐍅𐌰𐌻𐌷𐌰𐌻𐌰𐌽𐌳𐌰 𐍄𐍉𐌾𐌰𐌹𐌸 𐍆𐌹𐌻𐌿 𐌳𐌿 𐌷𐌹𐌻𐍀𐌰𐌽 𐍂𐌰𐌶𐌳𐌰, 𐌾𐌰𐌷 𐍃𐌹𐌽𐌳 𐌻𐌰𐌹𐍃𐌴𐌹𐌽𐌹𐌲𐌰𐍂𐌳𐌴𐌹𐍃 𐌸𐌰𐍂𐌴𐌹 𐌱𐌰𐍂𐌽𐌰 𐌹𐌽 𐍅𐌰𐌻𐌷𐌹𐍃𐌺𐌰𐌹 𐍂𐌰𐌶𐌳𐌰𐌹 𐌻𐌰𐌹𐍃𐌾𐌰𐌽𐌳.
#
# 𐌸𐌰𐍄𐌰 𐍃𐌹𐌽𐌳 𐌰𐌻𐌳𐌰𐌹 𐍅𐌰𐌹𐌷𐍄𐍉𐍃 𐌳𐌿 𐍅𐌹𐍃𐍃𐌴𐍃 𐌸𐌿.
#
# gu 1058
# અંતિમ નારીવાદી વિદ્વાન કેરોલીન હીલબ્રને અવલોકિત કર્યુ કે સ્ત્રીઓના જીવનચરિત્રો અને આત્મચરિત્રોએ નારીવાદી સક્રીયતાવાદના બીજા આંદોલન દરમ્યાનની ભૂમિકાઓમાં પરિવર્તન લાવ્યુ હતુ.  તેણીએ રજૂ કર્યુ કે નેન્સી મીલફોર્ડનું 1970નું જીવનચરિત્ર ઝેલ્ડા "સ્ત્રીઓના જીવનચરિત્રોના નવા યુગની શરુઆત હતી,કારણ કે " માત્ર 1970માં જ્યારે આપણે ઝેલ્ડાજ નહી જેનો નાશ ફીટ્ઝેરેલ્ડકરેલો તેને વાંચવા તૈયાર હતા પણ તેણીને ફીટ્ઝરેલ્ડ કહેલું :તેણીની વાર્તાઓ ચડિયાતી નથી તે પણ જાણવા તૈયાર હતા. મે સાર્ટોન્સની જર્નલ ઓફ સોલીટ્યુડ ના પ્રકાશન સાથેના કાળને, હીલબ્રમે 1973ને સ્ત્રીઓના જીવનચરિત્રો માટેનો સંક્રાન્તિકાળ બતાવ્યો,તે એક પહેલો દાખલો હતો જેમાં સ્ત્રી પોતાની જીવન વાર્તા જણાવે છે,"દર્દમાં પણ સુંદરતા"ની શોધ તરીકે કે અને "આધ્યાત્મિક ઉપાદાનોમાં પ્રકોપ"ની રુપાંતરિતા તરીકે નહી પણ,સ્ત્રીઓ પરના પહેલાના સુગમ્ય પ્રતિબંધોની સ્વીકારિતા સાથે:તેમની પીડાઓ,તેમના પર કરેલા પ્રકોપો,અને તેઓની"પોતાના જીવન પરના નિયંત્રણો અને અધિકારો માટેની આકાંક્ષાની જાહેર કબૂલાત".
#
#
# એફ-ડિસ્ટ્રીબ્યુશન સાથે I-1 ,nT-I  સ્વતંત્રતાની ડીગ્રી. એફ-ડિસ્ટ્રીબ્યુશનએ કુદરતી ઉમેદવાર છે કારણ કે કસોટીની બાબત સ્કવેરની બે રકમનો ભાગકાર છે જેની પાસે સાય-સ્કવેર ડિસ્ટ્રીબ્યુશનછે.
#
# guw 452
# Aliho dopo he mẹ nukunhunhun dé nọ wá vivọnu te wẹ eyin e lẹzun apadewhe nukunhunhun yọyọ devo tọn. Taidi apajlẹ, Egipti dowhenu tọn jẹ didiọ ji to whenue jonọ susu lẹ wá tin to ṣẹnsẹn yetọn. E wá lẹzun apadewhe nukunhunhun otò Pẹlsia, Gleki, Lomu po otò Malénu lẹ tọn po tọn.
#
# tn 947
# God games di kaiwa ele tse di etsisang setho ka gore batshamiki ba leba sectshaba se bone ba kgonang go se laola sone se sena kitgso ya se se diragalang. Ere ntswa God game e arogana thata dilo dingwe le metshameko e mo go yone go agiwang kgotsa go dirwang tlhokomelo kana e edirisang karolo ya go etsisa setho, batshamiki ba god game bone ba kgona fela go laola morafe wa bone osa itse. Ga ba kgone go bolelela ditlhophana dingwe gore di dire eng,jaaka go diragala mo metshamekong e mengwe,lefa batshamiki ba gonwe ba kgona go phadisanya le batshamiki ba bangwe ba dirisa merafe kgotsa balatedi ba bone. Mo godimo ga mo,batshamiki ba neetswe maatla a lekanang le a modimo golo mo go sa bonaleng mo metshamekong e mengwe, jaaka maatla a go laola loapi, go fetola bopego ya lefatshe,le go segafatsa kgotsa go hutsa merafe e mengwe e farologaneng
#
# Nngwe ya dimela di tshwana  mmidi  kgotsa dinawa, di ka tsewa fela jaaka merogo.
#
# to 673
# tutuhina
#
# tēvunga
#
# tpi 874
# Nambawan tokples bilong Tailan i Tok Tai.
#
# .bl .bq .cw .eh .mf .ss .sx
#
# tr 1862
# Vazgeçemediğim, şairin ilk kitabı Garip'ten dört sene sonra yayınlandı. Bu süre içerisinde Orhan Veli'nin şiir anlayışında bazı değişiklikler de oldu. Bu yüzden Vazgeçemediğim'de hem Garip'teki şiirlere benzer şiirler hem de onlardan ayrılan şiirler yer buldu.
#
# ODTÜ'ye giren öğrenciler, üniversitenin öğretim dilinin İngilizce olmasından dolayı, üniversite hayatının ilk eğitim döneminin başında İngilizce yeterlilik sınavına girmek zorundadır. Üniversite tarafından yapılan İngilizcede yeterlilik sınavından 59.50 ve üzeri not alanlar bölümlerine geçmeye hak kazanırken, sınavda geçersiz not alan öğrenciler İngilizce hazırlık programına alınırlar. Yine üniversite belirli koşulları sağlaması koşuluyla üniversite dışındaki TOEFL veya benzeri sınavlardan alınan notlarla, öğrencilerin bölümlerine geçmesine olanak tanımaktadır.
#
# trv 2072
# (2.748)
#
# (54)
#
# ts 377
# Xikwembu hakanyingi xi vona xi ri hava miri wa nyama, xithlela xiri hava vununa kumbe vusati, hambiswiritano nhlamuselo ya ku tumbuluxa misava  yi vangele leswaku xikwembu xihlamuseriwa hi vununa.
#
# Thekinoloji ("Ntivovuthlarhi hita kuvumba", risuka eka viti ra Xigriki τέχνη, techne, "Vupfapfarhuti kumbe Vutshila"; kuhlanganisa na -λογία, -logia) i nhlengelo wa vutshila, vuswikoti na maendlele yo tumbuluxa switirhisiwa kumbe vukorhokeri kumbe kuhetisisa vukambisisi bya Sayensi. Thekinoloji yinga thlela yi hlamuseriwa tanihi vutivi bya maendlelo ya mintirho.
#
# tt 1179
# Церера •
# Плутон •
# Һаумеа •
# Макемаке •
# Эрида •
# Кандидатлар:
# Седна •
# Орк •
# Квавар •
# Гоңгоң •
# Салация
#
# Биредә климат уртача, җылы җәй һәм йомшак кыш хас. Гыйнварның уртача температурасы — минус 6,6–5 °C, июльнеке — плюс 17–18,2 °C. Кышын көньяк җилләр, җәен көнчыгыш һәм төньяк-көнчыгыш җилләр исә. Җилнең уртача тизлеге 3 м/сек. Еллык явым-төшем күләме 520—640 мм.
#
# tum 182
# Chaholi ni chiyuni icho ntchifipa kweni chili na mahungwa yatuba mu singo ndipo pa chiNgerezi bakuti raven.
#
# Alofi ni msumba ukulu wa boma mu chalo cha Niue.
#
# tw 1105
# Tete Chinese a wɔtwerɛ sane kasa fa dwuma a obi di ho kaa biribi faa ɔtwerɛfoɔ abrabɔ aberɛ a wɔn rekyerɛ adwuma bi mu.  Dwumadie bi a a America scholar Burton Watson ka faa "links bi a tete Chinafoɔ ka faa art ne papa ne bɔne  ho". Ɛnam sɛ na Du Fu anwonsɛm pii fa papa ne bɔne ne abakwasɛm ho nti, saa dwumadie titire ho hia yie paa. Adeɛ baako a Chinese abakwasɛm twerɛfoɔ William Hung kae ne sɛ,mpɛmpii no China anwonsɛm no yɛ ketewa, a wɔyi nnoɔma a ɛho hia firi mu, a anka ɛwɔ sɛ obi a wɔkakyerɛ no a ɔte kurom hɔ hu. Wɔn a wɔte hɔ mprempren a wɔkenkan no, " sɛdeɛ yɛhunu mmerɛ no sɛ ɛyɛ, beaɛ no nnoɔma a ɛwɔ hɔ no mma no nyɛ saa, sɛ yɛde yɛnho to so sɛ ɛnnyɛ papa a nsunsuansoɔ a ɛbɛba ne sɛ yannte anwonsɛm no ase anaa sɛ yadi nkuguo sɛ yɛbɛte ne nyinaa ase". Stephen Owen de nsusuiɛ a ɛtɔ so mmiɛnsa a ɛfa Du Fu ho baa sɛ, wɔnkasa mfa nnoɔma a ɔtwerɛfoɔ no twereɛɛ a ɛfa ɔnoa abrabɔ ho, kyɛn nnoɔma bi ɛho hia  a wayi afiri anwonsɛm a watwerɛ nom.
#
# Florence Dolphyne yɛ suapɔn mu kyerɛkyerɛni (Lecturer) ne nhwehwɛmufoɔ.
#
# ty 238
# E òire no Pōrīnetia farāni ò Faaa, i Tahiti.
#
# E toru tupuaì mouà :
#
# tyv 1637
# 3. Путь длиною в полвека
#
# Онаарының падежинде турар чүве ады -ны деп кожумактыг болур.
#
# udm 695
# Шри Чинмой ― Индуизмын гуру. Индуизм сярысь книгаосын автор, суредась, кылбурчи, спортсмен но музыкант.
#
# Камчаткаын уно вулканъёс вань. Соос ЮНЕСКО-лэн списоказ пыртэмын.
#
# ug 1565
# كونتېينېر (ئېنگلىزچە: Intermodal container ياكى container، تەلەپپۇزى: كونتېينېر) ئادەتتە دۆلەت ئىچى ياكى خەلىقئارالىق يۈك تىرانسىپورتىدا ، بولۇپمۇ تۆمۈر يول، دېڭىز يولى، ۋە قاراماي يولدا، دائىم ئىشلىتىدىغان ئۆلچەملىك يۈك قويۇش، ساقلاش ساندۇقىنى كۆرستىدۇ. مەسىلەن چوڭ كېمىلەر دائىم بىر نەچچە مىڭ ھەتتا ئۇنىڭدىنمۇ ئارتۇق كونتېينېر بىلەن بىر دۆلەتتىن يەنە بىر دۆلەتكە يۈك توشۇيدۇ.
#
# يېقىنقى يىللاردىن بۇيان سىڭدۈرمە سىستېما دېگەن ئۇقۇم بىزنىڭ كۈندىلىك تۇرمۇشىمىزغا سىڭىپ كىرىشكە باشلىدى ھەم بۇنىڭدىن كىيىنكى ئەڭ قىزىق نۇقتا تېخنىكا يۈزلىنىشمۇ مۇشۇ تەرەپكە قاراپ بولىۋاتىدۇ. بىزنىڭ بۇ جەھەتتىكى خادىملىرىمىزنى بارماق بىلەن سانىساقمۇ بارماقلىرىمىز ئېشىپ قالامدىكىن دەيمەن. بۇ جەھەتتىكى بوشلۇق پەقەت بىزنىڭ ئۇيغۇر مىللىتىمىز ئارىسىدىلا ئەمەس بەلكى پۈتۈن مەملىكەت خاراكتېرلىك بولغان بىر زور < ئىختىساس ئىگىلىرى كرىزىسى> .
#
# uk 3800
# Для арафундійських мов раніше вживалася назва алфендійська мова (алфендіо), коли вони ще вважалися єдиною мовою.
#
# Траплялися у Дніпровських плавнях і вовки, але найчастіше, особливо у холодні зимові місяці, до місцевості заходили вовки, які мешкали у більш північних районах. На вологих місцях, по берегах річок зустрічалися: видра, полівка водяна, бурозубка водяна, кутора водяна та кутора мала.
#
# ur 1620
# غزالہ ایک فری لانس مصنفہ بھی ہیں
# اور انہوں نے سندھ اور پاکستان میں تعلیم کی پالیسی پر متعدد مضامین لکھے ہیں۔
# انہوں نے ڈان نیوز
# ، فرائیڈے ٹائمز
# اور دی ایکسپریس ٹریبیون میں بھی لکھا ہے۔
#
# پیر شاہ جیونہ نے جد امجد مخدوم جلال الدین سرخ بخاری خاندان غلامان کے عہد میں تبلیغ دین کی خاطر برصغیر ہند میں تشریف لائے۔ اس وقت ان کے ہم عصر اور قریبی احباب غوث بہاوالحق زکریا ملتانی، خواجہ فرید الدین گنج شکر اور شہباز قلندر تھے۔ اسی طرح پیر شاہ جیونہ کے ایک اور بزرگ مخدوم جہانیاں جہاں گشت کے خلیفہ مجدد الف ثانی کے جدالمجد امام رفیع الدین تھے
#
# uz 1116
# Rossiya ishchilarini asta-sekin markaziy osiyolik ishchi kuchi bilan almashtirishga qaratilgan hukumat siyosati, ayniqsa, 2000-2010-yillar oralig'ida chet elga miyaning oqishi sabab bo'ldi, bu erda, jumladan, 18 yoshdan oshgan erkaklarning katta qismi. 40 kishi o'z pul o'tkazmalari bilan davlat byudjetining muhim moddasini tashkil qiladi. Prezident Shavkat Mirziyoev 2017-yildan boshlab muhojirlik jarayonini orqaga surishga, xalq taʼlimi va mamlakatni qayta rivojlantirishga akademik shaxslarni jalb qilishga urinib koʻrgan aperturistik siyosatni amalga oshirdi.
#
# Yonilgʻi distillyatlaridagi kislorod va oltingugurtli birikmalarni yoʻqotishda ishqor bilan tozalash usuli ham qoʻllanadi. Bu jarayonda tozalanayotgan mahsulotga ishqor va suv qoʻshilib, hosil boʻlgan birikmani mahsulotdan ajratib olinadi.
#
# ve 304
# Viral hemorrhagic fevers ndi vhulwadze ha khombo vhu pfukhelaho nga luvhilo. Tsumbo dzi katela Ebola virus disease, Lassa fever, Rift valley fever, Marburg virus disease na Bolivian hemorrhagic fever. Viral hemorrhagic fevers ndi vhulwadze vhu ne vhu nga kona u vha tshiwo tsha lushaka. [xxxix] Maanda a uri vhu phadalale nga luvhilo uri vhu vhe tshiwo tsha lushaka zwo fhungudzea vhunga vhu tshi phadalala nga musi hu na u kwamana na munwe muthu lwa tsini, na muthu o kavhiwaho una tshifinga tshipfufhi tsha u lovha kana u lwala lu shushaho. Tshifhinga ndi tshipfufhi vhukati ha uri muthu o kavhiwaho uri a pfukhisele vhulwadze nga uri tsumba dwadze ndi zwone zwiitaho madoketala vha tavhanye u fhandekana muthu are na vhulwadze, zwa thivhela u pfukhisela vhulwadze hunwe.
#
# Steynsburg ndi ḓorobo ino wanala Kapa Vhubvaḓuvha kha la Afurika Tshipembe.
#
# vec 1583
# Altri progetti
# Modeło:Comuni del departemento Vandia
#
# vep 1467
# San Paulu jagase 9 zonha, ned alajagasoiš 32 lidnrajonha (port. subprefeitura).
#
# Sportkeskuz 1960-nzil vozil
#
# vi 1289
# Cyrtodactylus ayeyarwadyensis là một loài thằn lằn trong họ Gekkonidae. Loài này được Bauer mô tả khoa học đầu tiên năm 2003.
#
# Sông Vaal /[invalid input: 'icon']ˈfɑːl/ là phụ lưu lớn nhất của sông Orange tại Nam Phi. Sông khởi nguồn từ dãy núi Drakensberg tại Mpumalanga, phía đông của Johannesburg và cách khoảng 30 km về phía bắc của Ermelo và chỉ cách Ấn Độ Dương khoảng 240 km. Sông sau đó chảy về phía tây rồi hợp lưu vào sông Orange ở tây nam của Kimberley thuộc tỉnh Bắc Cape. Sông có chiều dài 1.120 km, và tạo thành ranh giới giữa các tỉnh Mpumalanga, Gauteng và tỉnh Tây Bắc ở bờ bắc, và Free State ở phía nam.
#
# vls 1018
# Zyn beste joar tout nu toe is zeker 2005, e joar woarin dat 'n nie ollêne de Rounde van Vloandern en Parys-Roubaix wonne, mor ouk de Rounde van België, 'n E3 Prys, 2 rittn in de Rounde van Vrankryk en weireldkampioen in Madrid.
#
# Midden de joaren tnegentig eet tie e eigen zaake begunnen in Roeseloare. 't Was dor ollemolle met Disney versierd en ter kwaamt vele volk.  Eén van de gebeurs moest do nie te vele van weten en dendienen ee joaren an e stik ruuze gemakt met Frank. Frank is ton moa gestopt met die taverne en j'is gelukkig weer in de muziek gesproengen. J'ee nu vele werk en j'is kontent.
#
# vo 1557
# La Bastide-du-Salat binon komot in ziläk: Ariège, in topäd: Midi-Pyrénée, in Fransän.
#
# Brizambourg labon belödanis 763 (1999).
#
# wa 1252
# Les frontires d' å cmince fourît co rcandjeyes e 1839 (Påye des 24 hagnons) pu e 1919 (Påye di Versaye).
#
# I paskeye voltî so des etrevéns ki s' passént di ç' tins la, come li "five des årmonreyes" (cwand tchaeke viyaedje vleut aveur si muzike.)
# %%
stats = []

for k, v in lang2texts.items():
    all_texts = ' '.join(v)
    stats.append({
        'lang': k,
        'pars': len(v),
        'chars': len(all_texts),
        'unique_chars': len(set(all_texts))
    })
stats = pd.DataFrame(stats)

# %%
stats.sort_values('chars', ascending=False)
# Out:
#     lang  pars    chars  unique_chars
# 2     de  5234  2052325           555
# 0     en  5481  1834006           720
# 7     es  4416  1744099           501
# 29    sh  2143  1685462           312
# 4     fr  6135  1631283           531
# ..   ...   ...      ...           ...
# 318   kj   121     1956            42
# 323  lrc    94     1503            14
# 321   ii   112     1495            82
# 320   ho    43     1032            28
# 322   aa     1      135            39
#
# [325 rows x 4 columns]

# %%
stats.sort_values('unique_chars', ascending=False)
# Out:
#              lang  pars   chars  unique_chars
# 12             zh  2894  327836          5278
# 152  zh-classical   985   77716          3501
# 11             ja  4546  585020          3437
# 100           wuu   486   47433          2771
# 64         zh-yue   779   64044          2753
# ..            ...   ...     ...           ...
# 318            kj   121    1956            42
# 322            aa     1     135            39
# 320            ho    43    1032            28
# 324           mus   660    2507            22
# 323           lrc    94    1503            14
#
# [325 rows x 4 columns]

# %%
stats[stats.lang.apply(lambda x: x in ['ru', 'mdf', 'myv'])]
# Out:
#     lang  pars    chars  unique_chars
# 6     ru  4626  1308708          1068
# 173  myv   848   159507           240
# 251  mdf   353    79764           244

# %%
import json

# %%
with open('lang2texts_wiki.json', 'w') as f:
    json.dump(lang2texts, f, ensure_ascii=False, indent='  ')

# %% [markdown]
# # Train the detection model

# %%
from sklearn.model_selection import train_test_split
train_texts = []
train_labels = []
test_texts = []
test_labels = []

for k, v in lang2texts.items():
    v2 = sorted(set(v))
    if len(v2) < 2:
        continue
    tr, ts = train_test_split(v2, test_size=0.2, random_state=1)
    train_texts.extend(tr)
    test_texts.extend(ts)
    train_labels.extend([k] * len(tr))
    test_labels.extend([k] * len(ts))
print(len(train_texts), len(test_texts))
# Out:
# 267754 67096

# %%
print(pd.Series(train_labels).value_counts()['myv'])
pd.Series(train_labels).value_counts()
# Out:
# 548
# en     4352
# fr     4240
# de     4139
# ru     3680
# pl     3656
#        ...
# ii       12
# cho      10
# mh        7
# kj        4
# ho        2
# Length: 323, dtype: int64

# %%
bible = pd.read_csv('erzya_bible.tsv', sep='\t')
print(bible.shape)
bible = bible.dropna()
print(bible.shape)
bible = bible[~bible.myv.str.startswith('Глава ')]
print(bible.shape)
print(bible.columns)
# Out:
# (12926, 4)
# (12899, 4)
# (12483, 4)
# Index(['Unnamed: 0', 'myv', 'ru', 'source'], dtype='object')

# %%
mbible = pd.read_csv('moksha_bible.tsv', sep='\t')
print(mbible.shape)
mbible = mbible.dropna()
print(mbible.shape)
mbible = mbible[~mbible.mdf.str.startswith('Глава ')]
print(mbible.shape)
print(mbible.columns)
# Out:
# (12517, 4)
# (12500, 4)
# (12344, 4)
# Index(['Unnamed: 0', 'mdf', 'ru', 'source'], dtype='object')

# %%
from nltk import sent_tokenize

def split_by_newline(text):
    return text.split('\n')

def split_overlapping_chunks(text, step=100, chunk_size=300):
    results = []
    for i in range(0, len(text), step):
        results.append(text[i:i+chunk_size])
    return results

def try_split(text, max_length=500):
    results = [text]
    parts = [text]
    
    for splitter in [split_by_newline, sent_tokenize, split_overlapping_chunks]:
        new_parts = []
        for part in parts:
            small_parts = [p.strip() for p in splitter(part)]
            for small_part in small_parts:
                if len(small_part) < 3: # the text is too short 
                    continue
                if len(small_part) <= min(len(part) * 0.5, max_length):
                    results.append(small_part)
                new_parts.append(small_part)
        parts = new_parts
    results.extend(parts)
    return sorted(set(results), key=lambda x: len(x))

# %%
train_texts_aug = []
train_labels_aug = []
for t, l in zip(tqdm(train_texts), train_labels):
    a = try_split(t)
    train_texts_aug.extend(a)
    train_labels_aug.extend([l]*len(a))
# Out:
#   0%|          | 0/267754 [00:00<?, ?it/s]

# %%
print(len(train_texts), len(train_texts_aug))
# Out:
# 267754 1393009

# %%
print(pd.Series(train_labels_aug).value_counts()['myv'])
pd.Series(train_labels_aug).value_counts()
# Out:
# 3127
# de     38694
# es     25238
# en     24849
# fr     21234
# ru     18800
#        ...
# cho       27
# ii        18
# mus       16
# kj         9
# ho         4
# Length: 323, dtype: int64

# %%
train_texts_aug.extend(bible.myv.tolist())
train_texts_aug.extend(bible.ru.tolist())

train_labels_aug.extend(['myv']*len(bible))
train_labels_aug.extend(['ru']*len(bible))

# %%
train_texts_aug.extend(mbible.mdf.tolist())
train_labels_aug.extend(['mdf']*len(mbible))

# %%
print(pd.Series(train_labels_aug).value_counts()['myv'])
print(pd.Series(train_labels_aug).value_counts()['mdf'])
pd.Series(train_labels_aug).value_counts()
# Out:
# 15610
# 13603
# de     38694
# ru     31283
# es     25238
# en     24849
# fr     21234
#        ...
# cho       27
# ii        18
# mus       16
# kj         9
# ho         4
# Length: 323, dtype: int64

# %% [markdown]
# #### Sklearn pipeline

# %%
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer
from sklearn.model_selection import cross_val_score, KFold

# %%
pipe = make_pipeline(
    HashingVectorizer(analyzer='char_wb', ngram_range=(1,4), n_features=100_000), 
    LogisticRegression(C=1e-4, max_iter=1_000, solver='saga')
)

# %%
# %%time
pipe.fit(train_texts_aug, train_labels_augg)
# Out:
# Wall time: 6h 16min 31s
# Pipeline(steps=[('hashingvectorizer',
#                  HashingVectorizer(analyzer='char_wb', n_features=100000,
#                                    ngram_range=(1, 4))),
#                 ('logisticregression',
#                  LogisticRegression(C=0.0001, max_iter=1000, solver='saga'))])

# %%
# %%time
preds = pipe.predict_proba(test_texts)
# Out:
# Wall time: 50 s

# %%
preds.argmax(1)
# Out:
# array([63, 63, 63, ..., 63, 63, 63], dtype=int64)

# %%
(pipe.classes_[preds.argmax(1)] == test_labels).mean()
# Out:
# 0.028913795159174912

# %%
pd.Series(pipe.classes_[preds.argmax(1)]).value_counts()
# Out:
# de    56051
# ru    11045
# dtype: int64

# %% [markdown]
# After 6 hours of training a model, it is still underfit as fuck...

# %% [markdown]
# #### Try FastText

# %%
import fasttext

# %%
with open('ft_train.txt', 'w') as f:
    for label, text in zip(train_labels_aug, train_texts_aug):
        f.write(f'__label__{label} ')
        f.write(text.replace('\n', ' ') + '\n')

# %% [markdown]
# model = fasttext.train_supervised(
#     input="ft_train.txt",
#     lr=0.1,
#     epoch=25,
#     wordNgrams=0,
#     bucket=100_000,
#     dim=50, # 16 seems to be OK
#     loss='softmax',
#     minn=1,
#     maxn=4,
#     minCount=1, # a larger number is required
# )

# %% [markdown]
# model = fasttext.train_supervised(
#     input="ft_train.txt",
#     lr=0.1, # 0.1 gives 38.8% / 0.5 gives 34.8% (overfitting?)
#     epoch=25, # 5 gives 38.8%  / 10 gives 49.5% / 25 gives 69%
#     wordNgrams=0,
#     bucket=100_000,  # default is 200K; 100K gives 38% acc, and 200K as well.
#     dim=32, # FB uses 16, but 32 is much better with me, and 64 seems +- the same
#     loss='softmax',
#     minn=1,
#     maxn=3, # if I decrease this to 3, the quality is no worse.
#     minCount=100, # a larger number is required  # 5 gets 39% accuracy with 650K words; 50 gets 38% acc with 50K words;
#     # 300 gets acc 38% with 6K words
# )

# %% [markdown]
# model = fasttext.train_supervised(
#     input="ft_train.txt",
#     lr=0.1, # 0.1 gives 38.8% / 0.5 gives 34.8% (overfitting?)
#     epoch=25, # 5 gives 38.8%  / 10 gives 49.5% /
#     wordNgrams=0,
#     bucket=200_000,  # default is 200K; 100K gives 38% acc, and 200K as well.
#     dim=64, # FB uses 16, but 32 is much better with me, and 64 seems +- the same
#     loss='softmax',
#     minn=1,
#     maxn=4, # if I decrease this to 3, the quality is no worse.
#     minCount=100, # a larger number is required  # 5 gets 39% accuracy with 650K words; 50 gets 38% acc with 50K words;
#     # 300 gets acc 38% with 6K words
# ) # 0.7683170382735185

# %%
model = fasttext.train_supervised(
    input="ft_train.txt", 
    lr=0.1, # 0.1 gives 38.8% / 0.5 gives 34.8% (overfitting?)
    epoch=25, # 5 gives 38.8%  / 10 gives 49.5% / 
    wordNgrams=0, 
    bucket=200_000,  # default is 200K; 100K gives 38% acc, and 200K as well.
    dim=64, # FB uses 16, but 32 is much better with me, and 64 seems +- the same
    loss='softmax',
    minn=1,
    maxn=4, # if I decrease this to 3, the quality is no worse.
    minCount=100, # a larger number is required  # 5 gets 39% accuracy with 650K words; 50 gets 38% acc with 50K words; 
    # 300 gets acc 38% with 6K words
)

# %% [markdown]
# Try a super long model

# %%
model = fasttext.train_supervised(
    input="ft_train.txt", 
    lr=0.05, # 0.1 gives 38.8% / 0.5 gives 34.8% (overfitting?)
    epoch=100, # 5 gives 38.8%  / 10 gives 49.5% / 
    wordNgrams=0, 
    bucket=200_000,  # default is 200K; 100K gives 38% acc, and 200K as well.
    dim=64, # FB uses 16, but 32 is much better with me, and 64 seems +- the same
    loss='softmax',
    minn=1,
    maxn=4, # if I decrease this to 3, the quality is no worse.
    minCount=100, # a larger number is required  # 5 gets 39% accuracy with 650K words; 50 gets 38% acc with 50K words; 
    # 300 gets acc 38% with 6K words
)

# %%
model.predict('пек вадря', k=5)
# Out:
# (('__label__myv', '__label__ru', '__label__lez', '__label__tg', '__label__be'),
#  array([0.74181491, 0.20231327, 0.0135121 , 0.00760135, 0.00718429]))

# %%
model.predict(['пек вадря', 'привет'], k=1)
# Out:
# ([['__label__myv'], ['__label__ru']],
#  [array([0.7418149], dtype=float32), array([0.9943341], dtype=float32)])

# %%
# %%time
ft_preds = model.predict([t.replace('\n', ' ') for t in test_texts])
# Out:
# Wall time: 9.3 s

# %%
ft_labels = [l[0][9:] for l in ft_preds[0]]

# %% [markdown]
# 77% accuracy, which is not bad! / 0.69618 in a smaller version / 0.76831 a middle one / 87% for longer training

# %%
(np.array(ft_labels) == test_labels).mean()
# Out:
# 0.8764009777035889

# %%
ft_sota = fasttext.load_model("../langid/lid.176.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
ft_sota_preds = ft_sota.predict([t.replace('\n', ' ') for t in test_texts])

# %%
(np.array([l[0][9:] for l in ft_sota_preds[0]]) == test_labels).mean()
# Out:
# 0.5884553475617026

# %%
model.save_model('../langid/lid.323.bin')

# %%
model = fasttext.load_model('../langid/lid.323.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
model.quantize(retrain=True, input="ft_train.txt", qnorm=True, cutoff=50_000)

# %%
len(model.words)
# Out:
# 2282

# %%
model.save_model('../langid/lid.323.ftz')

# %%
# %%time
ft_preds = model.predict([t.replace('\n', ' ') for t in test_texts])
# Out:
# Wall time: 25.1 s

# %% [markdown]
# After compression, the model retains 89% accuracy - even more than the large one. Probably, due to longer training.

# %%
ft_labels = [l[0][9:] for l in ft_preds[0]]
(np.array(ft_labels) == test_labels).mean()
# Out:
# 0.8900828663407655

# %% [markdown]
# # More quality estimation

# %%
import fasttext

# %%
model = fasttext.load_model('../langid/lid.323.ftz')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
import json

# %%
with open('lang2texts_wiki.json', 'r') as f:
    lang2texts= json.load(f)

# %%
from sklearn.model_selection import train_test_split
train_texts = []
train_labels = []
test_texts = []
test_labels = []

for k, v in lang2texts.items():
    v2 = sorted(set(v))
    if len(v2) < 2:
        continue
    tr, ts = train_test_split(v2, test_size=0.2, random_state=1)
    train_texts.extend(tr)
    test_texts.extend(ts)
    train_labels.extend([k] * len(tr))
    test_labels.extend([k] * len(ts))
print(len(train_texts), len(test_texts))
# Out:
# 267754 67096

# %%
len(train_texts)
# Out:
# 267754

# %%
# %%time
ft_preds = model.predict([t.replace('\n', ' ') for t in test_texts])
# Out:
# Wall time: 15.9 s

# %%
import numpy as np

# %%
ft_labels = [l[0][9:] for l in ft_preds[0]]
(np.array(ft_labels) == test_labels).mean()
# Out:
# 0.8900828663407655

# %%
from sklearn.metrics import classification_report

# %%
len(set(test_labels))
# Out:
# 323

# %%
print(classification_report(test_labels, ft_labels))
# Out:
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\david\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
